# %%
#Mount drive files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
dataBertAbstractPath = 'drive/My Drive/Year5/csc4006 Final Project/data/bert_encodings/bert_abstract_all.7z'
dataBertAbstractFile = 'drive/My Drive/Year5/csc4006 Final Project/data/bert_encodings/'
os.path.isfile(dataBertAbstractPath)
# Out:
# False

# %%
# !apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# /usr/bin/p7zip: cannot read dataBertAbstractPath

# %%
# Out:
# /usr/bin/p7zip: cannot read dataBertAbstractPath

# %%
# !pip install pyunpack
# !pip install patool

# %%
from pyunpack import Archive
Archive(dataBertAbstractPath).extractall(dataBertAbstractFile)
# Out:
# ---------------------------------------------------------------------------
# PatoolError                               Traceback (most recent call last)
# <ipython-input-25-6d2c98350527> in <module>()
#       1 from pyunpack import Archive
# ----> 2 Archive(dataBertAbstractPath).extractall(dataBertAbstractFile)
#
# /usr/local/lib/python3.6/dist-packages/pyunpack/__init__.py in extractall(self, directory, auto_create_dir, patool_path)
#      88                 self.extractall_zipfile(directory)
#      89             else:
# ---> 90                 self.extractall_patool(directory, patool_path)
#      91
#      92         if self.backend == 'zipfile':
#
# /usr/local/lib/python3.6/dist-packages/pyunpack/__init__.py in extractall_patool(self, directory, patool_path)
#      60             raise PatoolError('patool timeout\n' + str(p.stdout) + '\n' + str(p.stderr))
#      61         if p.return_code:
# ---> 62             raise PatoolError('patool can not unpack\n' + str(p.stderr))
# ...
